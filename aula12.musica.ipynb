# %%
import polars as pl

# %%
arquivo_info = 'Music Info.csv'
arquivo_user = 'User Listening History.csv'

try:

 df_musica = pl.read_csv(arquivo_info)
 df_execucao = pl.read_csv(arquivo_user)

 #print(df_info.glimpse())
 #print(df_user.glimpse())
 df_execucao_agrupado = df_execucao.group_by('track_id').agg(pl.col('playcount').sum().alias("plays"))
 print(df_execucao_agrupado.head())


 df_merge = df_musica.join(df_execucao_agrupado, left_on='track_id', right_on='track_id', how='left')
 
 
 
 #print(df_merge.head())
 #print(df_merge.glimpse())






except Exception as e :
    print( "erro")
# Out:
# shape: (5, 2)
# ┌────────────────────┬───────┐
# │ track_id           ┆ plays │
# │ ---                ┆ ---   │
# │ str                ┆ i64   │
# ╞════════════════════╪═══════╡
# │ TROAOOX128F9322089 ┆ 11    │
# │ TRUILAH128E0781F3B ┆ 23    │
# │ TRLJIIS12903CADBB8 ┆ 6     │
# │ TRCSVEQ128F4226132 ┆ 42    │
# │ TRUPSZX128F427FE7F ┆ 209   │
# └────────────────────┴───────┘

# %%
# top 10 de musicas mais tocadas 

top10_musicas = df_merge.group_by('name').agg(pl.col('plays').sum().alias("total_plays")).sort(by="total_plays", descending=True)
print(top10_musicas.head(10))
# Out:
# shape: (10, 2)
# ┌───────────────────────┬─────────────┐
# │ name                  ┆ total_plays │
# │ ---                   ┆ ---         │
# │ str                   ┆ i64         │
# ╞═══════════════════════╪═════════════╡
# │ Revelry               ┆ 527893      │
# │ Alejandro             ┆ 111615      │
# │ Gears                 ┆ 111596      │
# │ Halo                  ┆ 91461       │
# │ Bring Me To Life      ┆ 91448       │
# │ Heartbreak Warfare    ┆ 87745       │
# │ Uprising              ┆ 87050       │
# │ Float On              ┆ 85079       │
# │ Party In The U.S.A.   ┆ 78443       │
# │ Bitter Sweet Symphony ┆ 76893       │
# └───────────────────────┴─────────────┘
